# %%
# 필요한 라이브러리 설치 및 임포트
# !pip install pandas

import pandas as pd
import datetime

# %% [markdown]
# ---

# %% [markdown]
# # [Step 2] 데이터 전처리

# %% [markdown]
# #### **<span style="color:blue">[2-0] air_21, air_22, weather_21, weather_22 데이터 로딩</span>**

# %%
# 데이터 로딩
air_21 = pd.read_csv('air_2021.csv',sep=",",encoding="utf-8",index_col=0)
air_22 = pd.read_csv('air_2022.csv',sep=",",encoding="utf-8",index_col=0)
weather_21 = pd.read_csv('weather_2021.csv',sep=",",encoding="cp949")
weather_22 = pd.read_csv('weather_2022.csv',sep=",",encoding="cp949")

# %% [markdown]
# #### **<span style="color:blue">[2-1] air_21, air_22 의 '측정일시'를 활용하여 'time' 변수 생성</span>**

# %% [markdown]
# * air_21, air_22 의 '측정일시'를 활용하여 'time'변수 생성
# * time 변수를 to_datetime으로 데이터 타입 변경
# * 참고: 미세먼지 데이터는 1시-24시, 날씨 데이터는 0시-23시로 구성되어 있습니다. [2-5]에서 미세먼지와 날씨 데이터를 time 기준으로 합치려면 날씨 기준이 동일해야 합니다. 미세먼지 데이터에서 time 변수 생성 시 이를 미리 고려(예:측정일시 값 -1)하세요.

# %%
# # 아래에 필요한 코드를 작성하고 결과를 확인합니다.

air_21['측정일시']=(air_21['측정일시']-1)*100
air_22['측정일시']=(air_22['측정일시']-1)*100
air_21['측정일시']=air_21['측정일시'].astype("str")
air_22['측정일시']=air_22['측정일시'].astype("str")
air_21['측정일시'] = pd.to_datetime(air_21['측정일시'])
air_22['측정일시'] = pd.to_datetime(air_22['측정일시'])
weather_21['일시'] = pd.to_datetime(weather_21['일시'])
weather_22['일시'] = pd.to_datetime(weather_22['일시'])

# %% [markdown]
# ---

# %% [markdown]
# #### **<span style="color:blue">[2-2] weather_21, weather_22 의 '일시'를 활용하여 'time' 변수 생성</span>**

# %% [markdown]
# * weather_21, weather_22 의 '일시'를 활용하여 'time'변수 생성
# * time 변수를 to_datetime으로 데이터 타입 변경

# %%
# 아래에 필요한 코드를 작성하고 결과를 확인합니다.
# weather_21["time"] = weather_21['일시'].dt.hour
# weather_22["time"] = weather_22['일시'].dt.hour
# weather_21["일시"][:24]

# %%
# air_21["time"]=air_21["측정일시"].dt.hour
# air_22["time"]=air_22["측정일시"].dt.hour
# air_21

# %% [markdown]
# ---

# %% [markdown]
# #### **<span style="color:blue">[2-3] 'time' 기준으로 데이터 합치기</span>**

# %% [markdown]
# * 미세먼지 데이터와 날씨 데이터를 'time' 기준으로 합쳐보세요.
# * df_21에는 'time' 기준으로 21년도 미세먼지, 날씨 데이터를 합쳐보세요.
# * df_22에는 'time' 기준으로 22년도 미세먼지, 날씨 데이터를 합쳐보세요.

# %%
# 아래에 필요한 코드를 작성하고 결과를 확인합니다.
df_21 = pd.merge(air_21,weather_21,left_on="측정일시",right_on="일시")
df_22 = pd.merge(air_22,weather_22,left_on="측정일시",right_on="일시")

# %%
df_21.tail(2)
# Out:
#           지역     망   측정소코드 측정소명                측정일시    SO2   CO     O3    NO2  \
# 8757  서울 종로구  도시대기  111123  종로구 2021-09-30 22:00:00  0.003  0.6  0.004  0.042
# 8758  서울 종로구  도시대기  111123  종로구 2021-09-30 23:00:00  0.003  0.6  0.003  0.042
#
#       PM10  ...  최저운고(100m ) 시정(10m)  지면상태(지면상태코드) 현상번호(국내식) 지면온도(°C)  \
# 8757  33.0  ...          NaN    2000           NaN       NaN     18.6
# 8758  29.0  ...          NaN    2000           NaN       NaN     18.1
#
#       지면온도 QC플래그  5cm 지중온도(°C)  10cm 지중온도(°C)  20cm 지중온도(°C)  30cm 지중온도(°C)
# 8757         NaN          23.0           22.8           22.9           22.9
# 8758         NaN          22.6           22.5           22.8           22.9
#
# [2 rows x 50 columns]

# %%
pd.options.display.max_columns = 50
df_21.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8759 entries, 0 to 8758
# Data columns (total 50 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   지역             8759 non-null   object
#  1   망              8759 non-null   object
#  2   측정소코드          8759 non-null   int64
#  3   측정소명           8759 non-null   object
#  4   측정일시           8759 non-null   datetime64[ns]
#  5   SO2            8647 non-null   float64
#  6   CO             8679 non-null   float64
#  7   O3             8662 non-null   float64
#  8   NO2            8679 non-null   float64
#  9   PM10           8654 non-null   float64
#  10  PM25           8662 non-null   float64
#  11  주소             8759 non-null   object
#  12  지점             8759 non-null   int64
#  13  지점명            8759 non-null   object
#  14  일시             8759 non-null   datetime64[ns]
#  15  기온(°C)         8759 non-null   float64
#  16  기온 QC플래그       0 non-null      float64
# ...

# %% [markdown]
# ---

# %% [markdown]
# #### **<span style="color:blue">[2-4] 사용하지 않을 변수 제거</span>**

# %% [markdown]
# * 머신러닝에 사용하지 않을 변수들을 제거해줍니다.
# * df_21, df_22에 사용할 변수들만 넣어보세요.

# %%
# df_21, df_22에 사용할 변수들만 할당
a=["3시간신적설(cm)","적설(cm)","측정소코드","망","지역","측정소명","주소","지점","지점명","측정일시","기온 QC플래그","강수량 QC플래그","풍속 QC플래그","풍향 QC플래그","습도 QC플래그","현지기압 QC플래그","해면기압 QC플래그","지면온도 QC플래그"]
# df_21 =df_21.drop(a,axis=1)
# df_22 =df_22.drop(a,axis=1)
# df_21.head()
b=["3시간신적설(cm)","적설(cm)","지면상태(지면상태코드)","현상번호(국내식)"]
# df_21 =df_21.drop(b,axis=1)
# df_22 =df_22.drop(b,axis=1)
c=["일조 QC플래그","일사 QC플래그"]
# df_21 =df_21.drop(c,axis=1)
# df_22 =df_22.drop(c,axis=1)
df_21.head(10)
# Out:
#        지역     망   측정소코드 측정소명                측정일시    SO2   CO     O3    NO2  \
# 0  서울 종로구  도시대기  111123  종로구 2021-10-01 00:00:00  0.003  0.6  0.002  0.039
# 1  서울 종로구  도시대기  111123  종로구 2021-10-01 01:00:00  0.003  0.6  0.002  0.035
# 2  서울 종로구  도시대기  111123  종로구 2021-10-01 02:00:00  0.003  0.6  0.002  0.033
# 3  서울 종로구  도시대기  111123  종로구 2021-10-01 03:00:00  0.003  0.6  0.002  0.030
# 4  서울 종로구  도시대기  111123  종로구 2021-10-01 04:00:00  0.003  0.5  0.003  0.026
# 5  서울 종로구  도시대기  111123  종로구 2021-10-01 05:00:00  0.003  0.5  0.002  0.025
# 6  서울 종로구  도시대기  111123  종로구 2021-10-01 06:00:00  0.003  0.5  0.002  0.024
# 7  서울 종로구  도시대기  111123  종로구 2021-10-01 07:00:00  0.003  0.5  0.005  0.023
# 8  서울 종로구  도시대기  111123  종로구 2021-10-01 08:00:00  0.003  0.5  0.011  0.020
# 9  서울 종로구  도시대기  111123  종로구 2021-10-01 09:00:00  0.003  0.6  0.026  0.016
#
#    PM10  PM25                주소   지점 지점명                  일시  기온(°C)  \
# 0  31.0  18.0  서울 종로구 종로35가길 19  108  서울 2021-10-01 00:00:00    19.2
# ...

# %%
df_22.tail(10)
# Out:
#           지역     망   측정소코드 측정소명                측정일시    SO2   CO     O3    NO2  \
# 2150  서울 종로구  도시대기  111123  종로구 2022-03-31 14:00:00  0.003  0.3  0.050  0.011
# 2151  서울 종로구  도시대기  111123  종로구 2022-03-31 15:00:00  0.002  0.3  0.049  0.009
# 2152  서울 종로구  도시대기  111123  종로구 2022-03-31 16:00:00  0.003  0.4  0.045  0.010
# 2153  서울 종로구  도시대기  111123  종로구 2022-03-31 17:00:00  0.003  0.4  0.043  0.011
# 2154  서울 종로구  도시대기  111123  종로구 2022-03-31 18:00:00  0.002  0.4  0.044  0.010
# 2155  서울 종로구  도시대기  111123  종로구 2022-03-31 19:00:00  0.002  0.4  0.036  0.017
# 2156  서울 종로구  도시대기  111123  종로구 2022-03-31 20:00:00  0.002  0.4  0.032  0.018
# 2157  서울 종로구  도시대기  111123  종로구 2022-03-31 21:00:00  0.003  0.3  0.038  0.013
# 2158  서울 종로구  도시대기  111123  종로구 2022-03-31 22:00:00  0.003  0.3  0.036  0.015
# 2159  서울 종로구  도시대기  111123  종로구 2022-03-31 23:00:00  0.002  0.4  0.033  0.017
#
#       PM10  PM25                주소   지점 지점명                  일시  기온(°C)  \
# ...

# %%
# time 변수를 index로 세팅
# df_21 = df_21.set_index("일시")
# df_22 = df_22.set_index("일시")
df_21.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8759 entries, 0 to 8758
# Data columns (total 50 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   지역             8759 non-null   object
#  1   망              8759 non-null   object
#  2   측정소코드          8759 non-null   int64
#  3   측정소명           8759 non-null   object
#  4   측정일시           8759 non-null   datetime64[ns]
#  5   SO2            8647 non-null   float64
#  6   CO             8679 non-null   float64
#  7   O3             8662 non-null   float64
#  8   NO2            8679 non-null   float64
#  9   PM10           8654 non-null   float64
#  10  PM25           8662 non-null   float64
#  11  주소             8759 non-null   object
#  12  지점             8759 non-null   int64
#  13  지점명            8759 non-null   object
#  14  일시             8759 non-null   datetime64[ns]
#  15  기온(°C)         8759 non-null   float64
#  16  기온 QC플래그       0 non-null      float64
# ...

# %% [markdown]
# ---

# %% [markdown]
# #### **<span style="color:blue">[2-5] 변수들의 결측치 처리</span>**

# %%
# df_21, df_22의 결측치 확인
df_21['10cm 지중온도(°C)'].info()
# print(df_21['최저운고(100m )'].mean())
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 8759 entries, 0 to 8758
# Series name: 10cm 지중온도(°C)
# Non-Null Count  Dtype
# --------------  -----
# 8754 non-null   float64
# dtypes: float64(1)
# memory usage: 136.9 KB

# %%
# df_21, df_22의 변수 중 '강수량(mm)'의 결측치를 처리

# df_21["강수량(mm)"] = df_21["강수량(mm)"].fillna(0)
# df_22["강수량(mm)"] = df_22["강수량(mm)"].fillna(0)

# %%
# df_21, df_22의 남은 결측치를 처리
# display(air_21["PM10"].info()) 20cm 지중온도(°C),30cm 지중온도(°C)
df_21["PM10"]=df_21["PM10"].interpolate()
df_21["SO2"]=df_21["SO2"].interpolate()
df_21["CO"]=df_21["CO"].interpolate()
df_21["O3"]=df_21["O3"].interpolate()
df_21["PM25"]=df_21["PM25"].interpolate()
df_21["풍향(16방위)"]=df_21["풍향(16방위)"].interpolate()
df_21["풍속(m/s)"]=df_21["풍속(m/s)"].fillna(df_21["풍속(m/s)"].mean())
df_21["일조(hr)"]=df_21["일조(hr)"].fillna(df_21["일조(hr)"].mean())
df_21["일사(MJ/m2)"]=df_21["일사(MJ/m2)"].fillna(df_21["일사(MJ/m2)"].mean())
df_21['전운량(10분위)'] = df_21["풍속(m/s)"].fillna(0)
df_21['운형(운형약어)'] = df_21['운형(운형약어)'].fillna(method='ffill')
df_21['최저운고(100m )'] = df_21['최저운고(100m )'].fillna(df_21['최저운고(100m )'].mean())
df_21['지면온도(°C)'] = df_21['지면온도(°C)'].fillna(df_21['지면온도(°C)'].mean())
df_21['5cm 지중온도(°C)'] =df_21['5cm 지중온도(°C)'].fillna(df_21['5cm 지중온도(°C)'].mean())
df_21['10cm 지중온도(°C)'] = df_21['10cm 지중온도(°C)'].fillna(df_21['10cm 지중온도(°C)'].mean())
df_21['20cm 지중온도(°C)'] = df_21['20cm 지중온도(°C)'].fillna(df_21['20cm 지중온도(°C)'].mean())
df_21['30cm 지중온도(°C)'] = df_21['30cm 지중온도(°C)'].fillna(df_21['30cm 지중온도(°C)'].mean())


df_22["PM10"]=df_22["PM10"].interpolate()
df_22["SO2"]=df_22["SO2"].interpolate()
df_22["CO"]=df_22["CO"].interpolate()
df_22["O3"]=df_22["O3"].interpolate()
df_22["PM25"]=df_22["PM25"].interpolate()
df_22["풍속(m/s)"]=df_22["풍속(m/s)"].fillna(df_22["풍속(m/s)"].mean())
df_22["풍향(16방위)"]=df_22["풍향(16방위)"].interpolate()
df_22["일조(hr)"]=df_22["일조(hr)"].fillna(df_22["일조(hr)"].mean())
df_22["일사(MJ/m2)"]=df_22["일사(MJ/m2)"].fillna(df_22["일사(MJ/m2)"].mean())
df_22['전운량(10분위)'] = df_22["풍속(m/s)"].fillna(0)
df_22['운형(운형약어)'] = df_22['운형(운형약어)'].fillna(method='ffill')
df_22['최저운고(100m )'] = df_22['최저운고(100m )'].fillna(df_22['최저운고(100m )'].mean())
df_22['지면온도(°C)'] = df_22['지면온도(°C)'].fillna(df_22['지면온도(°C)'].mean())
df_22['5cm 지중온도(°C)'] =df_22['5cm 지중온도(°C)'].fillna(df_22['5cm 지중온도(°C)'].mean())
df_22['10cm 지중온도(°C)'] = df_22['10cm 지중온도(°C)'].fillna(df_22['10cm 지중온도(°C)'].mean())
df_22['20cm 지중온도(°C)'] = df_22['20cm 지중온도(°C)'].fillna(df_22['20cm 지중온도(°C)'].mean())
df_22['30cm 지중온도(°C)'] = df_22['30cm 지중온도(°C)'].fillna(df_22['30cm 지중온도(°C)'].mean())

# %%
# df_21, df_22의 결측치 재확인
df_21['운형(운형약어)'] = df_21['운형(운형약어)'].fillna("Sc")
df_22['운형(운형약어)'] = df_22['운형(운형약어)'].fillna("Sc")
df_21.isnull().sum()
# Out:
# 지역                  0
# 망                   0
# 측정소코드               0
# 측정소명                0
# 측정일시                0
# SO2                 0
# CO                  0
# O3                  0
# NO2                80
# PM10                0
# PM25                0
# 주소                  0
# 지점                  0
# 지점명                 0
# 일시                  0
# 기온(°C)              0
# 기온 QC플래그         8759
# 강수량(mm)          7810
# 강수량 QC플래그        6996
# 풍속(m/s)             0
# 풍속 QC플래그         8757
# 풍향(16방위)            0
# 풍향 QC플래그         8757
# 습도(%)               0
# 습도 QC플래그         8759
# 증기압(hPa)            0
# 이슬점온도(°C)           0
# 현지기압(hPa)           0
# 현지기압 QC플래그       8759
# 해면기압(hPa)           0
# 해면기압 QC플래그       8759
# 일조(hr)              0
# 일조 QC플래그         4791
# 일사(MJ/m2)           0
# 일사 QC플래그         4791
# 적설(cm)           8380
# 3시간신적설(cm)       8730
# 전운량(10분위)           0
# 중하층운량(10분위)         0
# 운형(운형약어)            0
# 최저운고(100m )         0
# ...

# %%
df_21["NO2"]=df_21["NO2"].interpolate()
df_22["NO2"]=df_22["NO2"].interpolate()
df_22.isnull().sum()
# Out:
# 지역                  0
# 망                   0
# 측정소코드               0
# 측정소명                0
# 측정일시                0
# SO2                 0
# CO                  0
# O3                  0
# NO2                 0
# PM10                0
# PM25                0
# 주소                  0
# 지점                  0
# 지점명                 0
# 일시                  0
# 기온(°C)              0
# 기온 QC플래그         2160
# 강수량(mm)          2079
# 강수량 QC플래그        1778
# 풍속(m/s)             0
# 풍속 QC플래그         2160
# 풍향(16방위)            0
# 풍향 QC플래그         2160
# 습도(%)               0
# 습도 QC플래그         2160
# 증기압(hPa)            0
# 이슬점온도(°C)           0
# 현지기압(hPa)           0
# 현지기압 QC플래그       2160
# 해면기압(hPa)           0
# 해면기압 QC플래그       2160
# 일조(hr)              0
# 일조 QC플래그         1071
# 일사(MJ/m2)           0
# 일사 QC플래그         1071
# 적설(cm)           2020
# 3시간신적설(cm)       2145
# 전운량(10분위)           0
# 중하층운량(10분위)         0
# 운형(운형약어)            0
# 최저운고(100m )         0
# ...

# %% [markdown]
# ---

# %% [markdown]
# #### **<span style="color:blue">[2-6] 전일 같은 시간 변수 추가</span>**

# %% [markdown]
# * 모델링에 유용한 변수로 전일 같은 시간(24시간 전) 미세먼지 농도 변수를 추가합니다.
# * 시계열 데이터 처리를 위한 shift 연산을 참고하세요.

# %%
# df_21, df_22의 index(time)를 month, day, hour 로 쪼개기 (year는 필요 없음)
df_21["month"] = df_21.index.month
df_21["day"] = df_21.index.day
df_21["hour"] = df_21.index.hour

df_22["month"] = df_22.index.month
df_22["day"] = df_22.index.day
df_22["hour"] = df_22.index.hour
df_21
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 2
#       1 # df_21, df_22의 index(time)를 month, day, hour 로 쪼개기 (year는 필요 없음)
# ----> 2 df_21["month"] = df_21.index.month
#       3 df_21["day"] = df_21.index.day
#       4 df_21["hour"] = df_21.index.hour
#
# AttributeError: 'Int64Index' object has no attribute 'month'

# %%
# df_21, df_22에 전일 같은 시간 미세먼지 농도 변수(PM10_lag1) 추가
# 전일 같은 시간은 24시간 전 입니다.
df_21["PM10_lag1"]=df_21["PM10"].shift(24)
df_22["PM10_lag1"]=df_22["PM10"].shift(24)
df_21["PM25_lag1"]=df_21["PM25"].shift(24)
df_22["PM25_lag1"]=df_22["PM25"].shift(24)
# df_21= df_21.drop("PM25_lag1",axis=1)
# df_22= df_22.drop("PM25_lag1",axis=1)

# %% [markdown]
# ---

# %% [markdown]
# #### **<span style="color:blue">[2-7] t+1 시점의 미세먼지 농도 데이터 생성</span>**

# %% [markdown]
# * t+1 시점은 1시간 후 입니다.
# * t+1 시점의 미세먼지 농도 변수를 생성하세요.
# * t+1 시점의 미세먼지 농도는 머신러닝 모델을 통해 예측하려는 y값(target) 입니다.

# %%
# df_21, df_22에 t+1 시점 변수(PM10_1) 추가
df_21["PM10_1"]=df_21["PM10"].shift(-1)
df_22["PM10_1"]=df_22["PM10"].shift(-1)

# %%
# 결측치가 있다면 처리
df_21["PM10_1"]=df_21["PM10_1"].interpolate()
df_22["PM10_1"]=df_22["PM10_1"].interpolate()
df_21["PM10_lag1"]=df_21["PM10_lag1"].fillna(df_21["PM10_lag1"].mean())
df_22["PM10_lag1"]=df_22["PM10_lag1"].fillna(df_22["PM10_lag1"].mean())

# %%
df_21.head(30)
# Out:
#                        SO2   CO     O3    NO2  PM10  PM25  기온(°C)  강수량(mm)  \
# 일시
# 2021-10-01 00:00:00  0.003  0.6  0.002  0.039  31.0  18.0    19.2      0.0
# 2021-10-01 01:00:00  0.003  0.6  0.002  0.035  27.0  16.0    18.7      0.0
# 2021-10-01 02:00:00  0.003  0.6  0.002  0.033  28.0  18.0    18.3      0.0
# 2021-10-01 03:00:00  0.003  0.6  0.002  0.030  26.0  16.0    17.7      0.0
# 2021-10-01 04:00:00  0.003  0.5  0.003  0.026  26.0  16.0    17.4      0.0
# 2021-10-01 05:00:00  0.003  0.5  0.002  0.025  22.0  14.0    17.2      0.0
# 2021-10-01 06:00:00  0.003  0.5  0.002  0.024  25.0  14.0    17.0      0.0
# 2021-10-01 07:00:00  0.003  0.5  0.005  0.023  24.0  14.0    17.0      0.0
# 2021-10-01 08:00:00  0.003  0.5  0.011  0.020  23.0  12.0    17.5      0.0
# 2021-10-01 09:00:00  0.003  0.6  0.026  0.016  40.0  22.0    19.8      0.0
# 2021-10-01 10:00:00  0.003  0.5  0.031  0.014  49.0  29.0    21.4      0.0
# ...

# %%
df_21 = df_21.drop("운형(운형약어)",axis=1)
df_22 = df_22.drop("운형(운형약어)",axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[252], line 1
# ----> 1 df_21 = df_21.drop("운형(운형약어)",axis=1)
#       2 df_22 = df_22.drop("운형(운형약어)",axis=1)
#
# File c:\Users\dufwn\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Users\dufwn\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %% [markdown]
# ---

# %% [markdown]
# #### **<span style="color:blue">[2-8] train, test 데이터 분리</span>**

# %% [markdown]
# * 21년도 데이터(df_21)를 train 데이터로 저장하세요. y 값을 제외하고 train_x로 저장한 후 y 값은 train_y로 저장하세요.
# * 22년도 데이터(df_22)를 test 데이터로 저장하세요. y 값을 제외하고 test_x로 저장한 후 y 값은 test_y로 저장하세요.
# * 각각의 데이터프레임을 csv 파일로 저장하세요. (train_x.csv / train_y.csv / test_x.csv / test_y.csv)
# * y값은 'PM10_1' 즉, t+1 시점의 미세먼지 농도입니다.

# %%
# 아래에 필요한 코드를 작성하고 결과를 확인합니다.
train_x = df_21.drop("PM10_1",axis=1)
train_y = df_21[["PM10_1"]]
test_x = df_22.drop("PM10_1",axis=1)
test_y = df_22[["PM10_1"]]

# %%
# train_x = pd.get_dummies(train_x,drop_first=True)
# test_x = pd.get_dummies(test_x,drop_first=True)

# %%
train_x
# Out:
#                        SO2   CO     O3    NO2  PM10  PM25  기온(°C)  강수량(mm)  \
# 일시
# 2021-10-01 00:00:00  0.003  0.6  0.002  0.039  31.0  18.0    19.2      0.0
# 2021-10-01 01:00:00  0.003  0.6  0.002  0.035  27.0  16.0    18.7      0.0
# 2021-10-01 02:00:00  0.003  0.6  0.002  0.033  28.0  18.0    18.3      0.0
# 2021-10-01 03:00:00  0.003  0.6  0.002  0.030  26.0  16.0    17.7      0.0
# 2021-10-01 04:00:00  0.003  0.5  0.003  0.026  26.0  16.0    17.4      0.0
# ...                    ...  ...    ...    ...   ...   ...     ...      ...
# 2021-09-30 19:00:00  0.003  0.7  0.020  0.036  35.0  24.0    22.7      0.0
# 2021-09-30 20:00:00  0.003  0.6  0.016  0.035  34.0  21.0    21.7      0.0
# 2021-09-30 21:00:00  0.003  0.6  0.012  0.036  30.0  19.0    20.9      0.0
# 2021-09-30 22:00:00  0.003  0.6  0.004  0.042  33.0  19.0    20.4      0.0
# 2021-09-30 23:00:00  0.003  0.6  0.003  0.042  29.0  17.0    19.7      0.0
#
# ...

# %%
train_x.shape, train_y.shape, test_x.shape, test_y.shape
# Out:
# ((8759, 30), (8759, 1), (2160, 30), (2160, 1))

# %%
# 각각의 데이터프레임을 csv 파일로 저장 (train_x.csv / train_y.csv / test_x.csv / test_y.csv)
train_x.to_csv("train_x.csv")
train_y.to_csv("train_y.csv")
test_x.to_csv("test_x.csv")
test_y.to_csv("test_y.csv")
